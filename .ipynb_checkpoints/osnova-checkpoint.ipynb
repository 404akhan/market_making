# %%
import numpy as np
import pandas as pd
import time
import random
from sortedcontainers import SortedList

random.seed(17)

# %%
from dataclasses import dataclass
from typing import Optional


@dataclass
class AnonTrade:  # Market trade
    timestamp: int
    side: str
    size: float
    price: float


@dataclass
class Order:  # Our own placed order
    timestamp: int
    order_id: int
    side: str
    size: float
    price: float


@dataclass
class OwnTrade:  # Execution of own placed order
    timestamp: int
    trade_id: int
    order_id: int
    side: str
    size: float
    price: float


@dataclass
class OrderbookSnapshotUpdate:  # Orderbook tick snapshot
    timestamp: int
    asks: list[tuple]  # tuple[price, size]
    bids: list[tuple]


@dataclass
class MdUpdate:  # Data of a tick
    orderbook: Optional[OrderbookSnapshotUpdate] = None
    trades: Optional[list[AnonTrade]] = None

# %%
btc_trades = pd.read_csv("../../../Downloads/md/md/btcusdt_Binance_LinearPerpetual/trades.csv")
btc_lobs = pd.read_csv("../../../Downloads/md/md/btcusdt_Binance_LinearPerpetual/lobs.csv")

# %%
eth_trades = pd.read_csv("../../../Downloads/md/md/ethusdt_Binance_LinearPerpetual/trades.csv")
eth_lobs = pd.read_csv("../../../Downloads/md/md/ethusdt_Binance_LinearPerpetual/lobs.csv")

# %%
np_btc_trades = btc_trades.to_numpy()
np_btc_lobs = btc_lobs.to_numpy()

trade_columns = btc_trades.columns.to_numpy()
lobs_columns = btc_lobs.columns.to_numpy()

btc_ti = {trade_columns[i]: i for i, col in enumerate(trade_columns)}
btc_li = {lobs_columns[i]: i for i, col in enumerate(lobs_columns)}

# %%
print(btc_trades.shape)
print(btc_lobs.shape)
# print(eth_trades.shape)
# print(eth_lobs.shape)

print(btc_trades.head())
print(btc_lobs.head())
print(np_btc_trades[0])
# Out:
# (5727714, 5)
# (2541356, 42)
#             receive_ts          exchange_ts aggro_side    price   size
# 0  1655942402624789714  1655942402623000000        BID  19977.5  0.001
# 1  1655942405293556247  1655942405292000000        BID  19977.5  0.041
# 2  1655942405293628020  1655942405292000000        BID  19977.5  0.036
# 3  1655942405293832021  1655942405292000000        BID  19977.5  0.001
# 4  1655942405293929517  1655942405292000000        BID  19977.5  0.001
#             receive_ts          exchange_ts  \
# 0  1655942402250125991  1655942402249000000
# 1  1655942402657844605  1655942402655000000
# 2  1655942403346968722  1655942403346000000
# 3  1655942404080791047  1655942404080000000
# 4  1655942404452706766  1655942404452000000
#
#    btcusdt:Binance:LinearPerpetual_ask_price_0  \
# 0                                      19977.5
# 1                                      19977.5
# 2                                      19977.5
# 3                                      19977.5
# 4                                      19977.5
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_0  \
# 0                                      0.079
# 1                                      0.078
# 2                                      0.079
# 3                                      0.079
# 4                                      0.079
#
#    btcusdt:Binance:LinearPerpetual_bid_price_0  \
# 0                                      19977.4
# 1                                      19977.4
# 2                                      19977.4
# 3                                      19977.4
# 4                                      19977.4
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_0  \
# 0                                     12.381
# 1                                     12.381
# 2                                     12.381
# 3                                     12.381
# 4                                     12.381
#
#    btcusdt:Binance:LinearPerpetual_ask_price_1  \
# 0                                      19977.8
# 1                                      19977.8
# 2                                      19977.8
# 3                                      19977.8
# 4                                      19977.8
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_1  \
# 0                                      0.003
# 1                                      0.003
# 2                                      0.003
# 3                                      0.003
# 4                                      0.003
#
#    btcusdt:Binance:LinearPerpetual_bid_price_1  \
# 0                                      19976.7
# 1                                      19977.3
# 2                                      19977.3
# 3                                      19977.3
# 4                                      19977.3
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_1  ...  \
# 0                                      0.066  ...
# 1                                      0.126  ...
# 2                                      0.126  ...
# 3                                      0.126  ...
# 4                                      0.126  ...
#
#    btcusdt:Binance:LinearPerpetual_bid_price_7  \
# 0                                      19975.7
# 1                                      19975.9
# 2                                      19975.9
# 3                                      19975.9
# 4                                      19975.9
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_7  \
# 0                                      4.455
# 1                                      0.246
# 2                                      0.246
# 3                                      0.246
# 4                                      0.246
#
#    btcusdt:Binance:LinearPerpetual_ask_price_8  \
# 0                                      19980.1
# 1                                      19980.1
# 2                                      19980.1
# 3                                      19980.1
# 4                                      19980.1
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_8  \
# 0                                       0.01
# 1                                       0.01
# 2                                       0.01
# 3                                       0.01
# 4                                       0.01
#
#    btcusdt:Binance:LinearPerpetual_bid_price_8  \
# 0                                      19975.6
# 1                                      19975.8
# 2                                      19975.8
# 3                                      19975.8
# 4                                      19975.8
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_8  \
# 0                                      1.529
# 1                                      0.686
# 2                                      0.686
# 3                                      0.686
# 4                                      0.686
#
#    btcusdt:Binance:LinearPerpetual_ask_price_9  \
# 0                                      19980.2
# 1                                      19980.2
# 2                                      19980.2
# 3                                      19980.2
# 4                                      19980.2
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_9  \
# 0                                       0.01
# 1                                       0.01
# 2                                       0.01
# 3                                       0.01
# 4                                       0.01
#
#    btcusdt:Binance:LinearPerpetual_bid_price_9  \
# 0                                      19975.4
# 1                                      19975.7
# 2                                      19975.7
# 3                                      19975.7
# 4                                      19975.7
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_9
# 0                                      1.641
# 1                                      4.455
# 2                                      4.455
# 3                                      4.455
# 4                                      4.455
#
# [5 rows x 42 columns]
# [1655942402624789714 1655942402623000000 'BID' 19977.5 0.001]

# %%
def load_md_from_file(pref, trades, lobs, ti, li) -> list[MdUpdate]:
    # TODO: load actual md
    pref_ask_price = pref + 'ask_price_'
    pref_ask_size = pref + 'ask_vol_'
    pref_bid_price = pref + 'bid_price_'
    pref_bid_size = pref + 'bid_vol_'
    
    mds = []
    i_tr = 0
    
    start_sec = time.time()
    print('Started parsing csv files...')
    for i_lobs in range(lobs.shape[0]):
        d = lobs[i_lobs]
        asks = [(d[li[pref_ask_price + str(i)]], d[li[pref_ask_size + str(i)]]) for i in range(10)]
        bids = [(d[li[pref_bid_price + str(i)]], d[li[pref_bid_size + str(i)]]) for i in range(10)]
        book = OrderbookSnapshotUpdate(timestamp = d[li[' exchange_ts']], asks = asks, bids = bids)
        
        anon_trades = []        
        while i_tr < trades.shape[0] and trades[i_tr][ti['exchange_ts']] < lobs[i_lobs][li[' exchange_ts']]:
            d = trades[i_tr]
            at = AnonTrade(timestamp=d[ti['exchange_ts']], side=d[ti['aggro_side']].lower(), size=d[ti['size']], price=d[ti['price']])    
            anon_trades.append(at)

            i_tr += 1
            if i_tr % 300000 == 0:
                print('Trade progress: %d, %.2f%%' % (i_tr, i_tr / trades.shape[0] * 100))
        
        mds.append(MdUpdate(orderbook = book, trades = anon_trades))
        
        if i_lobs % 300000 == 0:
            print('Lobs progress: %d, %.2f%%' % (i_lobs, i_lobs / lobs.shape[0] * 100))
            
    print('Finished in %d seconds' % (time.time() - start_sec))
    return mds
                 

loaded_md = load_md_from_file('btcusdt:Binance:LinearPerpetual_', np_btc_trades, np_btc_lobs, btc_ti, btc_li)
# Out:
# Started parsing csv files...
# Lobs progress: 0, 0.00%
# Trade progress: 100000, 1.75%
# Trade progress: 200000, 3.49%
# Trade progress: 300000, 5.24%
# Lobs progress: 100000, 3.93%
# Trade progress: 400000, 6.98%
# Trade progress: 500000, 8.73%
# Lobs progress: 200000, 7.87%
# Trade progress: 600000, 10.48%
# Lobs progress: 300000, 11.80%
# Trade progress: 700000, 12.22%
# Trade progress: 800000, 13.97%
# Lobs progress: 400000, 15.74%
# Trade progress: 900000, 15.71%
# Trade progress: 1000000, 17.46%
# Lobs progress: 500000, 19.67%
# Trade progress: 1100000, 19.20%
# Lobs progress: 600000, 23.61%
# Trade progress: 1200000, 20.95%
# Trade progress: 1300000, 22.70%
# Lobs progress: 700000, 27.54%
# Trade progress: 1400000, 24.44%
# Trade progress: 1500000, 26.19%
# Lobs progress: 800000, 31.48%
# Trade progress: 1600000, 27.93%
# Trade progress: 1700000, 29.68%
# Lobs progress: 900000, 35.41%
# Trade progress: 1800000, 31.43%
# Trade progress: 1900000, 33.17%
# Lobs progress: 1000000, 39.35%
# Trade progress: 2000000, 34.92%
# Trade progress: 2100000, 36.66%
# Trade progress: 2200000, 38.41%
# Lobs progress: 1100000, 43.28%
# Trade progress: 2300000, 40.16%
# Trade progress: 2400000, 41.90%
# Lobs progress: 1200000, 47.22%
# Trade progress: 2500000, 43.65%
# Trade progress: 2600000, 45.39%
# Lobs progress: 1300000, 51.15%
# Trade progress: 2700000, 47.14%
# Trade progress: 2800000, 48.89%
# Trade progress: 2900000, 50.63%
# Lobs progress: 1400000, 55.09%
# Trade progress: 3000000, 52.38%
# Trade progress: 3100000, 54.12%
# Trade progress: 3200000, 55.87%
# Lobs progress: 1500000, 59.02%
# Trade progress: 3300000, 57.61%
# Trade progress: 3400000, 59.36%
# Lobs progress: 1600000, 62.96%
# Trade progress: 3500000, 61.11%
# Trade progress: 3600000, 62.85%
# Trade progress: 3700000, 64.60%
# Lobs progress: 1700000, 66.89%
# Trade progress: 3800000, 66.34%
# Trade progress: 3900000, 68.09%
# Lobs progress: 1800000, 70.83%
# Trade progress: 4000000, 69.84%
# Trade progress: 4100000, 71.58%
# Lobs progress: 1900000, 74.76%
# Trade progress: 4200000, 73.33%
# Lobs progress: 2000000, 78.70%
# Trade progress: 4300000, 75.07%
# Trade progress: 4400000, 76.82%
# Trade progress: 4500000, 78.57%
# Lobs progress: 2100000, 82.63%
# Trade progress: 4600000, 80.31%
# Trade progress: 4700000, 82.06%
# Trade progress: 4800000, 83.80%
# Trade progress: 4900000, 85.55%
# Lobs progress: 2200000, 86.57%
# Trade progress: 5000000, 87.29%
# Trade progress: 5100000, 89.04%
# Lobs progress: 2300000, 90.50%
# Trade progress: 5200000, 90.79%
# Trade progress: 5300000, 92.53%
# Trade progress: 5400000, 94.28%
# Lobs progress: 2400000, 94.44%
# Trade progress: 5500000, 96.02%
# Trade progress: 5600000, 97.77%
# Lobs progress: 2500000, 98.37%
# Trade progress: 5700000, 99.52%
# Finished in 107 seconds

# %%
class Strategy:
    def __init__(self, max_position: float) -> None:
        self.max_position = max_position
        self.position = 0
        self.cur_balance = 0
        self.total_executed_trades = 0
        self.total_canceled_trades = 0
        
        self.t0_cancel = 10 * 1000 * 1000 * 1000 # 10,000 seconds
        self.active_positions = SortedList()
        self.order2time = {}
        
    
    def get_best_ask(self, md):
        return md.orderbook.asks[0][0]
    
    
    def get_best_bid(self, md):
        return md.orderbook.bids[0][0]
    
    
    def get_PNL(self, md):
        price = (self.get_best_ask(md) + self.get_best_bid(md)) / 2
        
        return price * self.position + self.cur_balance
    
    
    def smart_AI(self, md):
        is_ask = random.randint(0, 1)
        if self.position > self.max_position:
            is_ask = 1
        if self.position < -self.max_position:
            is_ask = 0
            
        if is_ask:
            side = 'ask'
            size = 0.001
            price = self.get_best_ask(md)
        else:
            side = 'bid'
            size = 0.001
            price = self.get_best_bid(md)
        
        return side, size, price
    
    
    def get_time(self, md):
        return md.orderbook.timestamp
    
    
    def print_stats(self, counter, md):
        if counter % 10000 == 0:
            print('Iteration %d - executed %d, canceled %d, position: %0.4f, balance: %.5f, PNL: %.3f' % 
                  (counter, self.total_executed_trades, self.total_canceled_trades, self.position, self.cur_balance, self.get_PNL(md)))
        return counter + 1
        
    
    def run(self, sim: "Sim"):
        counter = 0
        while True:
            try:
                md, executed = sim.tick()
                if md == None:
                    print('End of data!')
                    break
                
                # calculate statistics
                self.total_executed_trades += len(executed)
                for order in executed:
                    if order.side == 'ask':
                        self.position -= order.size
                        self.cur_balance += order.size * order.price
                    if order.side == 'bid':
                        self.position += order.size
                        self.cur_balance -= order.size * order.price
                    
                    active = (self.order2time[order.order_id], order.order_id)
                    self.active_positions.remove(active)
                
                # place order
                side, size, price = self.smart_AI(md)
                order_id = sim.place_order(side, size, price)
                
                # record it
                self.active_positions.add((self.get_time(md), order_id))
                self.order2time[order_id] = self.get_time(md)
                
                # cancel old orders
                while len(self.active_positions) and self.active_positions[0][0] + self.t0_cancel < self.get_time(md):
                    timestamp, order_id = self.active_positions.pop(0)
                    success = sim.cancel_order(order_id)
                    if success:
                        self.total_canceled_trades += 1
                    
                counter = self.print_stats(counter, md)
            except StopIteration:
                break

# %%
class Sim:
    def __init__(self, execution_latency: float, md_latency: float) -> None:
        self.md = iter(loaded_md)
        self.cur_time = 0
        self.execution_latency = execution_latency
        self.md_latency = md_latency
        
        self.unique_id = 1
        self.queue = {}
        self.arrived_orders = {}
        self.inside_book = {}
        self.executed_queue = []

    
    def gen_id(self):
        ans = self.unique_id
        self.unique_id += 1
        return ans
        
        
    def tick(self) -> MdUpdate:
        md = next(self.md, None)
        if md == None: return None, None
        
        self.cur_time = md.orderbook.timestamp
        
        self.prepare_orders()
        self.execute_orders(md)
        executed = self.prepare_trades()
        
        return md, executed

    
    def prepare_orders(self): # wait for execution_latency to accept the order
        processed_ids = []
        for order in self.queue.values():
            if order.timestamp + self.execution_latency <= self.cur_time:
                self.arrived_orders[order.order_id] = order
                processed_ids.append(order.order_id)

        for order_id in processed_ids:     
            self.queue.pop(order_id)
            
    
    def prepare_trades(self): # wait for md_latency to return trades
        executed = []
        new_queue = []
        
        for trade in self.executed_queue:
            if trade.timestamp + self.md_latency <= self.cur_time:
                executed.append(trade)
            else:
                new_queue.append(trade)
        
        self.executed_queue = new_queue
        return executed

        
    def matches_book(self, order, md):
        book = md.orderbook
        if order.side == 'bid': # buying
            if book.asks[0][0] <= order.price:
                return (True, book.asks[0][0])
        if order.side == 'ask':
            if book.bids[0][0] >= order.price:
                return (True, book.bids[0][0])
        return (False, -1)
    
    
    def matches_trade_flow(self, order, condensed_trades):
        asks, bids = condensed_trades
        if order.side == 'bid':
            return bids[0] and bids[1] <= order.price
        if order.side == 'ask':
            return asks[0] and asks[1] >= order.price
        
    
    def get_condensed_trades(self, md):
        mn_bid, mx_ask = 0, 0
        exist_bid, exist_ask = False, False
        
        for tr in md.trades:
            if tr.side == 'bid':
                if not exist_bid or tr.price < mn_bid:
                    mn_bid = tr.price
                    exist_bid = True
            if tr.side == 'ask':
                if not exist_ask or tr.price > mx_ask:
                    mx_ask = tr.price
                    exist_ask = True
            
        return ((exist_ask, mx_ask), (exist_bid, mn_bid))
    
    
    def execute_orders(self, md):
        # Market orders
        for order in self.arrived_orders.values():
            matched, price = self.matches_book(order, md)
            if matched:
                self.executed_queue.append(OwnTrade(self.cur_time, self.gen_id(), order.order_id, order.side, order.size, price))
            else:
                self.inside_book[order.order_id] = order
        self.arrived_orders = {}
        
        # Limit orders
        condensed_trades = self.get_condensed_trades(md)
        processed_ids = []
        
        for order in self.inside_book.values():
            if self.matches_trade_flow(order, condensed_trades):
                self.executed_queue.append(OwnTrade(self.cur_time, self.gen_id(), order.order_id, order.side, order.size, order.price))
                processed_ids.append(order.order_id)

        for order_id in processed_ids:        
            self.inside_book.pop(order_id)

    
    def place_order(self, side, size, price):
        order_id = self.gen_id()
        self.queue[order_id] = Order(self.cur_time, order_id, side, size, price)
        return order_id

        
    def cancel_order(self, order_id):
        canceled = False
        if order_id in self.queue:
            self.queue.pop(order_id)
            canceled = True
        if order_id in self.arrived_orders:
            self.arrived_orders.pop(order_id)
            canceled = True
        if order_id in self.inside_book:
            self.inside_book.pop(order_id)
            canceled = True
        return canceled

# %%
strategy = Strategy(10)
sim = Sim(10, 10)
strategy.run(sim)
# Out:
# Iteration 0 - executed 0, canceled 0, position: 0.0000, balance: 0.00000, PNL: 0.000
# Iteration 10000 - executed 8214, canceled 1683, position: -0.1060, balance: 2111.65320, PNL: -8.267
# Iteration 20000 - executed 16836, canceled 3071, position: -0.4580, balance: 9153.66530, PNL: -34.754
# Iteration 30000 - executed 25448, canceled 4490, position: -0.5160, balance: 10311.49420, PNL: -97.284
# Iteration 40000 - executed 34114, canceled 5775, position: -0.2160, balance: 4259.21850, PNL: -92.350
# Iteration 50000 - executed 43065, canceled 6895, position: -0.2410, balance: 4725.55940, PNL: -173.513
# Iteration 60000 - executed 52044, canceled 7910, position: 0.2440, balance: -5127.95920, PNL: -183.580
# Iteration 70000 - executed 61004, canceled 8923, position: 0.1940, balance: -4106.33310, PNL: -164.146
# Iteration 80000 - executed 69442, canceled 10468, position: 0.0200, balance: -579.11250, PNL: -173.275
# Iteration 90000 - executed 77927, canceled 12019, position: -0.4990, balance: 9967.57600, PNL: -216.290
# Iteration 100000 - executed 86759, canceled 13202, position: -0.2830, balance: 5550.11690, PNL: -225.135
# Iteration 110000 - executed 95298, canceled 14628, position: 0.2900, balance: -6144.34790, PNL: -231.871
# Iteration 120000 - executed 103259, canceled 16658, position: 0.5130, balance: -10700.09230, PNL: -244.921
# Iteration 130000 - executed 111320, canceled 18593, position: 0.6820, balance: -14148.33950, PNL: -273.629
# Iteration 140000 - executed 119493, canceled 20458, position: 0.1750, balance: -3831.80070, PNL: -259.141
# Iteration 150000 - executed 127717, canceled 22230, position: 0.2570, balance: -5505.68970, PNL: -245.851
# Iteration 160000 - executed 136553, canceled 23340, position: 0.2210, balance: -4782.89480, PNL: -247.831
# Iteration 170000 - executed 144870, canceled 25001, position: 0.7860, balance: -16360.64800, PNL: -284.079
# Iteration 180000 - executed 152421, canceled 27377, position: 1.1790, balance: -24402.38810, PNL: -303.098
# Iteration 190000 - executed 160505, canceled 29378, position: 1.5590, balance: -32169.34060, PNL: -349.605
# Iteration 200000 - executed 168656, canceled 31254, position: 1.2860, balance: -26611.37710, PNL: -423.595
# Iteration 210000 - executed 176614, canceled 33219, position: 0.9000, balance: -18754.71740, PNL: -411.952
# Iteration 220000 - executed 184068, canceled 35797, position: 0.7140, balance: -14988.88170, PNL: -430.814
# Iteration 230000 - executed 191221, canceled 38682, position: 1.0110, balance: -21044.90960, PNL: -462.314
# Iteration 240000 - executed 198459, canceled 41368, position: 0.5530, balance: -11727.36090, PNL: -456.585
# Iteration 250000 - executed 205736, canceled 44151, position: 0.3320, balance: -7230.08540, PNL: -467.229
# Iteration 260000 - executed 212680, canceled 47284, position: 0.4180, balance: -8986.72600, PNL: -474.469
# Iteration 270000 - executed 219971, canceled 49801, position: 0.1590, balance: -3731.55500, PNL: -487.200
# Iteration 280000 - executed 227752, canceled 52121, position: 0.4160, balance: -8985.04920, PNL: -500.209
# Iteration 290000 - executed 235379, canceled 54533, position: 0.3410, balance: -7456.36350, PNL: -487.909
# Iteration 300000 - executed 243549, canceled 56322, position: 0.4930, balance: -10567.22370, PNL: -496.047
# Iteration 310000 - executed 250609, canceled 59187, position: 1.2390, balance: -25799.03360, PNL: -587.428
# Iteration 320000 - executed 258737, canceled 61187, position: 1.2070, balance: -25153.89660, PNL: -669.962
# Iteration 330000 - executed 266494, canceled 63388, position: 0.1800, balance: -4304.38880, PNL: -645.106
# Iteration 340000 - executed 273902, canceled 66002, position: 0.3120, balance: -6997.70710, PNL: -665.308
# Iteration 350000 - executed 281354, canceled 68453, position: -0.1460, balance: 2296.04500, PNL: -671.018
# Iteration 360000 - executed 288663, canceled 71221, position: -0.1950, balance: 3282.43710, PNL: -677.028
# Iteration 370000 - executed 296148, canceled 73746, position: 0.6120, balance: -13101.62570, PNL: -695.131
# Iteration 380000 - executed 302690, canceled 77145, position: 0.8820, balance: -18583.73830, PNL: -695.235
# Iteration 390000 - executed 309666, canceled 80296, position: 1.2000, balance: -25033.59960, PNL: -754.780
# Iteration 400000 - executed 317202, canceled 82674, position: 0.5940, balance: -12777.04210, PNL: -753.027
# Iteration 410000 - executed 325184, canceled 84652, position: 0.8720, balance: -18410.42480, PNL: -746.888
# Iteration 420000 - executed 332107, canceled 87787, position: 1.6210, balance: -33574.59510, PNL: -805.513
# Iteration 430000 - executed 340179, canceled 89636, position: 1.4650, balance: -30424.63220, PNL: -805.921
# Iteration 440000 - executed 347876, canceled 91989, position: 1.5200, balance: -31537.22620, PNL: -876.318
# Iteration 450000 - executed 355306, canceled 94566, position: 1.3780, balance: -28674.12160, PNL: -839.142
# Iteration 460000 - executed 363178, canceled 96705, position: 1.5020, balance: -31182.41840, PNL: -865.675
# Iteration 470000 - executed 370837, canceled 99041, position: 0.9370, balance: -19788.69380, PNL: -834.542
# Iteration 480000 - executed 378734, canceled 101214, position: 1.2100, balance: -25323.47970, PNL: -792.363
# Iteration 490000 - executed 386261, canceled 103586, position: 1.7630, balance: -36540.45760, PNL: -799.070
# Iteration 500000 - executed 394214, canceled 105723, position: 1.6500, balance: -34260.04030, PNL: -678.828
# Iteration 510000 - executed 401920, canceled 107955, position: 2.2360, balance: -46185.55190, PNL: -730.467
# Iteration 520000 - executed 408752, canceled 111112, position: 2.6500, balance: -54609.06120, PNL: -747.944
# Iteration 530000 - executed 416025, canceled 113837, position: 2.5810, balance: -53217.76460, PNL: -678.283
# Iteration 540000 - executed 423805, canceled 116164, position: 2.8770, balance: -59251.55020, PNL: -660.438
# Iteration 550000 - executed 431667, canceled 118255, position: 3.6110, balance: -74190.42600, PNL: -909.695
# Iteration 560000 - executed 438600, canceled 121239, position: 2.6680, balance: -55043.45630, PNL: -828.763
# Iteration 570000 - executed 445569, canceled 124310, position: 2.6510, balance: -54719.56020, PNL: -856.145
# Iteration 580000 - executed 453152, canceled 126678, position: 2.3320, balance: -48236.21290, PNL: -740.252
# Iteration 590000 - executed 461321, canceled 128551, position: 2.7390, balance: -56540.33270, PNL: -677.195
# Iteration 600000 - executed 469234, canceled 130584, position: 3.2180, balance: -66330.67090, PNL: -718.708
# Iteration 610000 - executed 477120, canceled 132791, position: 3.7200, balance: -76568.55070, PNL: -770.017
# Iteration 620000 - executed 484412, canceled 135453, position: 4.0320, balance: -82932.75650, PNL: -786.200
# Iteration 630000 - executed 492064, canceled 137814, position: 4.6760, balance: -96052.57890, PNL: -1001.423
# Iteration 640000 - executed 499609, canceled 140233, position: 4.5190, balance: -92863.48920, PNL: -1066.105
# Iteration 650000 - executed 507709, canceled 142123, position: 4.2570, balance: -87541.78650, PNL: -1076.370
# Iteration 660000 - executed 515337, canceled 144538, position: 4.4350, balance: -91163.48890, PNL: -1083.982
# Iteration 670000 - executed 522899, canceled 146944, position: 4.0830, balance: -84012.87230, PNL: -990.171
# Iteration 680000 - executed 529978, canceled 149914, position: 3.3860, balance: -69844.43840, PNL: -954.745
# Iteration 690000 - executed 537648, canceled 152282, position: 2.9060, balance: -60076.50870, PNL: -770.715
# Iteration 700000 - executed 546158, canceled 153818, position: 2.5320, balance: -52430.98720, PNL: -384.335
# Iteration 710000 - executed 555045, canceled 154913, position: 2.5110, balance: -52013.29060, PNL: -268.988
# Iteration 720000 - executed 563695, canceled 156179, position: 2.7190, balance: -56298.49130, PNL: -386.743
# Iteration 730000 - executed 572221, canceled 157730, position: 3.0030, balance: -62143.34310, PNL: -436.348
# Iteration 740000 - executed 579737, canceled 160157, position: 3.1090, balance: -64325.63890, PNL: -370.244
# Iteration 750000 - executed 587680, canceled 162221, position: 3.6660, balance: -75777.65260, PNL: -437.503
# Iteration 760000 - executed 595900, canceled 163998, position: 3.2840, balance: -67925.76110, PNL: -334.309
# Iteration 770000 - executed 603685, canceled 166259, position: 3.8830, balance: -80260.31990, PNL: -460.981
# Iteration 780000 - executed 612171, canceled 167774, position: 4.6450, balance: -95898.25220, PNL: -768.884
# Iteration 790000 - executed 620504, canceled 169349, position: 4.5800, balance: -94570.95870, PNL: -730.652
# Iteration 800000 - executed 628668, canceled 171173, position: 5.1560, balance: -106371.00810, PNL: -820.728
# Iteration 810000 - executed 636097, canceled 173689, position: 5.6350, balance: -116179.26400, PNL: -994.511
# Iteration 820000 - executed 643192, canceled 176681, position: 5.0180, balance: -103565.16780, PNL: -852.479
# Iteration 830000 - executed 650439, canceled 179415, position: 4.1730, balance: -86270.45160, PNL: -807.620
# Iteration 840000 - executed 658054, canceled 181850, position: 4.4100, balance: -91126.64560, PNL: -988.230
# Iteration 850000 - executed 665480, canceled 184448, position: 4.2740, balance: -88352.61790, PNL: -977.740
# Iteration 860000 - executed 673801, canceled 186139, position: 3.4670, balance: -71830.88820, PNL: -691.689
# Iteration 870000 - executed 682067, canceled 187775, position: 3.1870, balance: -66081.59970, PNL: -493.299
# Iteration 880000 - executed 690855, canceled 189096, position: 3.1090, balance: -64471.80600, PNL: -344.484
# Iteration 890000 - executed 699314, canceled 190558, position: 3.6020, balance: -74625.41940, PNL: -595.855
# Iteration 900000 - executed 707315, canceled 192569, position: 3.3270, balance: -68974.83710, PNL: -468.746
# Iteration 910000 - executed 714547, canceled 195419, position: 3.3990, balance: -70457.41590, PNL: -650.114
# Iteration 920000 - executed 722451, canceled 197392, position: 3.4770, balance: -72063.66470, PNL: -824.629
# Iteration 930000 - executed 729829, canceled 200038, position: 3.3350, balance: -69162.21020, PNL: -807.216
# Iteration 940000 - executed 737367, canceled 202509, position: 3.5830, balance: -74248.91220, PNL: -842.737
# Iteration 950000 - executed 744967, canceled 204936, position: 3.4970, balance: -72490.51380, PNL: -825.968
# Iteration 960000 - executed 753224, canceled 206671, position: 3.4300, balance: -71129.20520, PNL: -591.427
# Iteration 970000 - executed 761175, canceled 208629, position: 3.4250, balance: -71030.66520, PNL: -571.394
# Iteration 980000 - executed 769342, canceled 210548, position: 3.4060, balance: -70641.10640, PNL: -543.412
# Iteration 990000 - executed 777283, canceled 212557, position: 3.3170, balance: -68816.07450, PNL: -530.820
# Iteration 1000000 - executed 784699, canceled 215214, position: 3.5650, balance: -73930.78520, PNL: -473.247
# Iteration 1010000 - executed 793251, canceled 216683, position: 3.7470, balance: -77676.94650, PNL: -750.474
# Iteration 1020000 - executed 801667, canceled 218275, position: 3.6730, balance: -76157.20280, PNL: -607.082
# Iteration 1030000 - executed 810190, canceled 219689, position: 3.9240, balance: -81304.35000, PNL: -885.305
# Iteration 1040000 - executed 818547, canceled 221330, position: 3.5890, balance: -74437.60170, PNL: -764.225
# Iteration 1050000 - executed 826902, canceled 223056, position: 2.9200, balance: -60691.11400, PNL: -575.468
# Iteration 1060000 - executed 835940, canceled 224039, position: 2.7660, balance: -57512.58790, PNL: -200.653
# Iteration 1070000 - executed 844960, canceled 224977, position: 2.9720, balance: -61787.80810, PNL: -195.931
# Iteration 1080000 - executed 854135, canceled 225841, position: 3.0230, balance: -62845.58170, PNL: -70.417
# Iteration 1090000 - executed 863097, canceled 226863, position: 3.0810, balance: -64052.30440, PNL: -144.508
# Iteration 1100000 - executed 872157, canceled 227828, position: 2.8970, balance: -60243.00950, PNL: -221.660
# Iteration 1110000 - executed 880073, canceled 229823, position: 2.7510, balance: -57222.95460, PNL: -147.545
# Iteration 1120000 - executed 888473, canceled 231500, position: 2.9630, balance: -61615.32330, PNL: -342.409
# Iteration 1130000 - executed 896828, canceled 233071, position: 2.6220, balance: -54562.32170, PNL: -264.504
# Iteration 1140000 - executed 904697, canceled 235156, position: 2.1870, balance: -45555.65190, PNL: -222.969
# Iteration 1150000 - executed 912776, canceled 237112, position: 2.4620, balance: -51265.62470, PNL: -285.852
# Iteration 1160000 - executed 921192, canceled 238697, position: 2.6840, balance: -55859.94360, PNL: -381.261
# Iteration 1170000 - executed 929342, canceled 240548, position: 2.6360, balance: -54872.67820, PNL: -388.535
# Iteration 1180000 - executed 937126, canceled 242699, position: 2.8200, balance: -58682.99140, PNL: -376.248
# Iteration 1190000 - executed 944764, canceled 245065, position: 2.6940, balance: -56081.32930, PNL: -360.384
# Iteration 1200000 - executed 952340, canceled 247581, position: 2.6340, balance: -54842.48130, PNL: -387.560
# Iteration 1210000 - executed 960044, canceled 249783, position: 2.0700, balance: -43196.65240, PNL: -434.696
# Iteration 1220000 - executed 967528, canceled 252173, position: 2.2180, balance: -46260.08700, PNL: -412.142
# Iteration 1230000 - executed 975228, canceled 254627, position: 2.1740, balance: -45357.99430, PNL: -464.786
# Iteration 1240000 - executed 982729, canceled 257134, position: 1.9010, balance: -39723.91300, PNL: -441.744
# Iteration 1250000 - executed 990687, canceled 259120, position: 2.2250, balance: -46425.85130, PNL: -529.108
# Iteration 1260000 - executed 998727, canceled 261155, position: 2.1950, balance: -45810.48350, PNL: -484.063
# Iteration 1270000 - executed 1005559, canceled 264278, position: 2.4370, balance: -50811.05330, PNL: -556.092
# Iteration 1280000 - executed 1013115, canceled 266797, position: 2.2210, balance: -46362.06990, PNL: -523.184
# Iteration 1290000 - executed 1021197, canceled 268684, position: 1.9710, balance: -41209.77220, PNL: -515.422
# Iteration 1300000 - executed 1029683, canceled 270233, position: 2.4050, balance: -50174.85860, PNL: -509.564
# Iteration 1310000 - executed 1038223, canceled 271690, position: 2.4150, balance: -50392.15370, PNL: -498.374
# Iteration 1320000 - executed 1046804, canceled 273094, position: 2.4100, balance: -50293.87960, PNL: -381.936
# Iteration 1330000 - executed 1055498, canceled 274468, position: 2.2460, balance: -46903.43570, PNL: -314.321
# Iteration 1340000 - executed 1063939, canceled 275949, position: 2.4950, balance: -52069.54780, PNL: -387.245
# Iteration 1350000 - executed 1072888, canceled 277066, position: 2.7920, balance: -58208.68910, PNL: -707.030
# Iteration 1360000 - executed 1081814, canceled 278126, position: 2.6760, balance: -55824.82290, PNL: -722.905
# Iteration 1370000 - executed 1090445, canceled 279512, position: 3.0130, balance: -62756.64310, PNL: -962.875
# Iteration 1380000 - executed 1099050, canceled 280877, position: 2.3360, balance: -48861.66240, PNL: -849.738
# Iteration 1390000 - executed 1107532, canceled 282296, position: 2.3340, balance: -48825.31550, PNL: -901.877
# Iteration 1400000 - executed 1115886, canceled 284039, position: 1.7260, balance: -36328.21700, PNL: -746.813
# Iteration 1410000 - executed 1123726, canceled 286154, position: 1.9080, balance: -40080.69690, PNL: -809.764
# Iteration 1420000 - executed 1131568, canceled 288380, position: 1.7340, balance: -36507.83000, PNL: -781.968
# Iteration 1430000 - executed 1139292, canceled 290566, position: 1.1220, balance: -23909.64140, PNL: -800.985
# Iteration 1440000 - executed 1147802, canceled 292159, position: 1.3220, balance: -28031.85340, PNL: -846.840
# Iteration 1450000 - executed 1156929, canceled 292982, position: 1.3870, balance: -29374.66880, PNL: -940.961
# Iteration 1460000 - executed 1165676, canceled 294270, position: 1.2060, balance: -25670.57770, PNL: -951.738
# Iteration 1470000 - executed 1174557, canceled 295416, position: 1.2610, balance: -26796.68090, PNL: -1039.306
# Iteration 1480000 - executed 1183496, canceled 296442, position: 1.0620, balance: -22736.32700, PNL: -1017.312
# Iteration 1490000 - executed 1192475, canceled 297469, position: 0.8210, balance: -17812.31200, PNL: -1018.059
# Iteration 1500000 - executed 1201423, canceled 298494, position: 1.0210, balance: -21903.42310, PNL: -1067.110
# Iteration 1510000 - executed 1210087, canceled 299831, position: 0.9670, balance: -20805.79670, PNL: -1049.648
# Iteration 1520000 - executed 1218364, canceled 301546, position: 0.3380, balance: -7959.08160, PNL: -1038.447
# Iteration 1530000 - executed 1227000, canceled 302956, position: 0.4480, balance: -10214.86390, PNL: -1045.312
# Iteration 1540000 - executed 1235380, canceled 304557, position: 0.1920, balance: -4982.41530, PNL: -1054.758
# Iteration 1550000 - executed 1243660, canceled 306241, position: 0.4440, balance: -10142.20350, PNL: -1059.318
# Iteration 1560000 - executed 1252237, canceled 307710, position: 0.0290, balance: -1642.66850, PNL: -1047.422
# Iteration 1570000 - executed 1260622, canceled 309319, position: 0.1900, balance: -4955.68320, PNL: -1054.917
# Iteration 1580000 - executed 1268867, canceled 311062, position: 0.0590, balance: -2270.58290, PNL: -1058.254
# Iteration 1590000 - executed 1277522, canceled 312436, position: -0.3320, balance: 5766.59030, PNL: -1065.289
# Iteration 1600000 - executed 1285370, canceled 314478, position: 0.6000, balance: -13400.44790, PNL: -1075.578
# Iteration 1610000 - executed 1292918, canceled 316996, position: -0.0560, balance: 75.12320, PNL: -1076.027
# Iteration 1620000 - executed 1300606, canceled 319233, position: -0.2860, balance: 4800.95520, PNL: -1079.190
# Iteration 1630000 - executed 1309061, canceled 320905, position: 0.0130, balance: -1347.03980, PNL: -1081.183
# Iteration 1640000 - executed 1317294, canceled 322605, position: 0.1380, balance: -3906.03790, PNL: -1088.209
# Iteration 1650000 - executed 1326162, canceled 323785, position: 0.5060, balance: -11419.91760, PNL: -1136.505
# Iteration 1660000 - executed 1334951, canceled 324976, position: 0.2950, balance: -7136.09390, PNL: -1137.313
# Iteration 1670000 - executed 1343324, canceled 326553, position: 0.5700, balance: -12731.76590, PNL: -1146.373
# Iteration 1680000 - executed 1351477, canceled 328456, position: 0.5190, balance: -11699.56150, PNL: -1145.411
# Iteration 1690000 - executed 1359645, canceled 330248, position: 0.2030, balance: -5271.02700, PNL: -1136.556
# Iteration 1700000 - executed 1368030, canceled 331831, position: 0.8240, balance: -17900.20050, PNL: -1158.786
# Iteration 1710000 - executed 1376553, canceled 333391, position: 1.1050, balance: -23605.69910, PNL: -1206.355
# Iteration 1720000 - executed 1384377, canceled 335571, position: 0.4310, balance: -9934.27000, PNL: -1190.702
# Iteration 1730000 - executed 1391812, canceled 338030, position: 0.0660, balance: -2532.35380, PNL: -1191.184
# Iteration 1740000 - executed 1399522, canceled 340351, position: 0.0560, balance: -2343.83570, PNL: -1207.285
# Iteration 1750000 - executed 1407878, canceled 342073, position: -0.4940, balance: 8820.49560, PNL: -1214.793
# Iteration 1760000 - executed 1416135, canceled 343764, position: -0.4370, balance: 7656.78700, PNL: -1220.453
# Iteration 1770000 - executed 1423846, canceled 346033, position: -0.2860, balance: 4591.72220, PNL: -1213.863
# Iteration 1780000 - executed 1431840, canceled 348076, position: -0.3560, balance: 6012.43530, PNL: -1227.376
# Iteration 1790000 - executed 1439655, canceled 350294, position: -0.2090, balance: 3020.64880, PNL: -1227.694
# Iteration 1800000 - executed 1447098, canceled 352770, position: 0.5120, balance: -11624.42000, PNL: -1244.465
# Iteration 1810000 - executed 1456014, canceled 353903, position: 0.6400, balance: -14230.33410, PNL: -1279.646
# Iteration 1820000 - executed 1464391, canceled 355465, position: 0.4090, balance: -9555.94660, PNL: -1256.539
# Iteration 1830000 - executed 1472347, canceled 357602, position: 0.5130, balance: -11675.83040, PNL: -1259.494
# Iteration 1840000 - executed 1479581, canceled 360287, position: 0.7610, balance: -16717.34000, PNL: -1273.111
# Iteration 1850000 - executed 1487277, canceled 362667, position: 1.4190, balance: -30072.98730, PNL: -1325.253
# Iteration 1860000 - executed 1495149, canceled 364745, position: 1.1470, balance: -24560.54130, PNL: -1277.646
# Iteration 1870000 - executed 1501870, canceled 367967, position: 1.8580, balance: -38978.25020, PNL: -1351.985
# Iteration 1880000 - executed 1509686, canceled 370252, position: 1.2780, balance: -27225.49370, PNL: -1288.931
# Iteration 1890000 - executed 1517138, canceled 372766, position: 1.2520, balance: -26696.76040, PNL: -1256.183
# Iteration 1900000 - executed 1525208, canceled 374664, position: 1.2200, balance: -26054.38070, PNL: -1235.982
# Iteration 1910000 - executed 1533163, canceled 376692, position: 1.6730, balance: -35264.43060, PNL: -1262.964
# Iteration 1920000 - executed 1540546, canceled 379318, position: 1.3940, balance: -29596.17150, PNL: -1246.742
# Iteration 1930000 - executed 1548265, canceled 381607, position: 1.4590, balance: -30915.27920, PNL: -1226.307
# Iteration 1940000 - executed 1556271, canceled 383625, position: 1.4290, balance: -30311.14720, PNL: -1207.776
# Iteration 1950000 - executed 1563820, canceled 386072, position: 1.5180, balance: -32128.20070, PNL: -1184.606
# Iteration 1960000 - executed 1571998, canceled 387897, position: 2.0160, balance: -42283.00750, PNL: -1166.183
# Iteration 1970000 - executed 1579954, canceled 389972, position: 1.9180, balance: -40286.64190, PNL: -1145.920
# Iteration 1980000 - executed 1587783, canceled 392133, position: 2.0730, balance: -43450.89470, PNL: -1147.702
# Iteration 1990000 - executed 1595382, canceled 394496, position: 2.0920, balance: -43841.55700, PNL: -1180.970
# Iteration 2000000 - executed 1602534, canceled 397168, position: 2.5180, balance: -52542.87750, PNL: -1136.271
# Iteration 2010000 - executed 1610014, canceled 399870, position: 3.5380, balance: -73366.01970, PNL: -1161.277
# Iteration 2020000 - executed 1617305, canceled 402482, position: 4.0710, balance: -84246.78800, PNL: -1172.130
# Iteration 2030000 - executed 1624596, canceled 405290, position: 3.9720, balance: -82229.50940, PNL: -1202.894
# Iteration 2040000 - executed 1632766, canceled 407130, position: 3.4340, balance: -71250.10030, PNL: -810.347
# Iteration 2050000 - executed 1640498, canceled 409427, position: 3.8480, balance: -79741.91570, PNL: -710.730
# Iteration 2060000 - executed 1649254, canceled 410702, position: 3.8720, balance: -80247.91940, PNL: -168.183
# Iteration 2070000 - executed 1658044, canceled 411876, position: 3.7500, balance: -77742.05480, PNL: -42.242
# Iteration 2080000 - executed 1666917, canceled 413003, position: 3.6990, balance: -76698.02930, PNL: 180.322
# Iteration 2090000 - executed 1675809, canceled 414079, position: 3.9030, balance: -80948.48180, PNL: 123.268
# Iteration 2100000 - executed 1684699, canceled 415279, position: 3.4750, balance: -72054.10320, PNL: 342.136
# Iteration 2110000 - executed 1693550, canceled 416406, position: 3.5060, balance: -72711.93910, PNL: 359.587
# Iteration 2120000 - executed 1701827, canceled 418113, position: 3.3570, balance: -69607.90740, PNL: 570.681
# Iteration 2130000 - executed 1710628, canceled 419301, position: 3.6060, balance: -74810.06660, PNL: 83.128
# Iteration 2140000 - executed 1719089, canceled 420812, position: 2.6330, balance: -54597.22770, PNL: 239.605
# Iteration 2150000 - executed 1728058, canceled 421852, position: 2.7840, balance: -57794.11570, PNL: 720.971
# Iteration 2160000 - executed 1736628, canceled 423253, position: 3.1940, balance: -66405.98690, PNL: 640.704
# Iteration 2170000 - executed 1744994, canceled 424907, position: 3.7120, balance: -77276.04870, PNL: 363.587
# Iteration 2180000 - executed 1753915, canceled 425999, position: 3.9330, balance: -81893.14270, PNL: 123.869
# Iteration 2190000 - executed 1762069, canceled 427847, position: 3.4150, balance: -71086.36050, PNL: 202.277
# Iteration 2200000 - executed 1769954, canceled 429972, position: 2.5860, balance: -53789.92080, PNL: 255.023
# Iteration 2210000 - executed 1777748, canceled 432174, position: 2.3020, balance: -47856.84170, PNL: 302.264
# Iteration 2220000 - executed 1785955, canceled 433870, position: 2.8490, balance: -59282.43940, PNL: -25.946
# Iteration 2230000 - executed 1793705, canceled 436100, position: 2.0610, balance: -42886.65880, PNL: 58.295
# Iteration 2240000 - executed 1802008, canceled 437885, position: 1.6820, balance: -35016.17660, PNL: -81.793
# Iteration 2250000 - executed 1809804, canceled 440130, position: 1.8700, balance: -38932.01310, PNL: -99.500
# Iteration 2260000 - executed 1817722, canceled 442211, position: 0.9540, balance: -19903.49430, PNL: -70.550
# Iteration 2270000 - executed 1824899, canceled 444948, position: 0.8890, balance: -18554.00830, PNL: -80.811
# Iteration 2280000 - executed 1831561, canceled 448171, position: 1.1090, balance: -23138.48680, PNL: -62.803
# Iteration 2290000 - executed 1838151, canceled 451759, position: 1.2590, balance: -26253.70530, PNL: -210.598
# Iteration 2300000 - executed 1845461, canceled 454471, position: 0.9110, balance: -19054.21440, PNL: -198.109
# Iteration 2310000 - executed 1853463, canceled 456438, position: 0.7690, balance: -16125.03030, PNL: -199.079
# Iteration 2320000 - executed 1859588, canceled 460248, position: 0.7500, balance: -15734.19600, PNL: -211.408
# Iteration 2330000 - executed 1866577, canceled 463326, position: 0.5750, balance: -12118.72110, PNL: -223.322
# Iteration 2340000 - executed 1875102, canceled 464817, position: 0.2660, balance: -5731.00300, PNL: -218.751
# Iteration 2350000 - executed 1883574, canceled 466373, position: 0.4680, balance: -9934.04440, PNL: -222.506
# Iteration 2360000 - executed 1891877, canceled 468039, position: 0.4510, balance: -9589.29190, PNL: -224.209
# Iteration 2370000 - executed 1900488, canceled 469398, position: 0.4880, balance: -10368.92120, PNL: -207.761
# Iteration 2380000 - executed 1908716, canceled 471234, position: 0.7500, balance: -15834.47830, PNL: -209.166
# Iteration 2390000 - executed 1917704, canceled 472274, position: 0.5660, balance: -11995.06900, PNL: -36.027
# Iteration 2400000 - executed 1926694, canceled 473257, position: 0.6980, balance: -14780.92680, PNL: -71.170
# Iteration 2410000 - executed 1935490, canceled 474467, position: 0.9520, balance: -20139.12550, PNL: -79.581
# Iteration 2420000 - executed 1944064, canceled 475861, position: 0.8120, balance: -17186.44060, PNL: -85.924
# Iteration 2430000 - executed 1952638, canceled 477280, position: 1.2240, balance: -25856.41820, PNL: -148.563
# Iteration 2440000 - executed 1960992, canceled 478909, position: 1.1640, balance: -24603.12540, PNL: -176.527
# Iteration 2450000 - executed 1969133, canceled 480823, position: 0.6610, balance: -14055.32130, PNL: -147.518
# Iteration 2460000 - executed 1977203, canceled 482726, position: 0.9670, balance: -20505.69310, PNL: -149.231
# Iteration 2470000 - executed 1983980, canceled 485820, position: 2.2300, balance: -47092.75370, PNL: -192.397
# Iteration 2480000 - executed 1991805, canceled 488141, position: 2.1150, balance: -44679.89850, PNL: 44.632
# Iteration 2490000 - executed 1999911, canceled 489985, position: 2.4810, balance: -52416.46830, PNL: 68.218
# Iteration 2500000 - executed 2007841, canceled 492016, position: 3.1530, balance: -66633.54840, PNL: -76.398
# Iteration 2510000 - executed 2014749, canceled 495097, position: 3.0910, balance: -65330.71820, PNL: -24.225
# Iteration 2520000 - executed 2022000, canceled 497817, position: 3.3160, balance: -70091.83320, PNL: -152.253
# Iteration 2530000 - executed 2029494, canceled 500375, position: 3.2080, balance: -67821.88750, PNL: -216.656
# Iteration 2540000 - executed 2037075, canceled 502870, position: 2.9310, balance: -61990.92860, PNL: -187.423
# End of data!
