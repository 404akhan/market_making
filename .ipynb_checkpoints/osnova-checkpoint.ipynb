# %%
import numpy as np
import pandas as pd
import time
import random
from sortedcontainers import SortedList

random.seed(17)

# %%
from dataclasses import dataclass
from typing import Optional


@dataclass
class AnonTrade:  # Market trade
    timestamp: int
    side: str
    size: float
    price: float


@dataclass
class Order:  # Our own placed order
    timestamp: int
    order_id: int
    side: str
    size: float
    price: float


@dataclass
class OwnTrade:  # Execution of own placed order
    timestamp: int
    trade_id: int
    order_id: int
    side: str
    size: float
    price: float


@dataclass
class OrderbookSnapshotUpdate:  # Orderbook tick snapshot
    timestamp: int
    asks: list[tuple]  # tuple[price, size]
    bids: list[tuple]


@dataclass
class MdUpdate:  # Data of a tick
    orderbook: Optional[OrderbookSnapshotUpdate] = None
    trades: Optional[list[AnonTrade]] = None

# %%
btc_trades = pd.read_csv("../../../Downloads/md/md/btcusdt_Binance_LinearPerpetual/trades.csv")
btc_lobs = pd.read_csv("../../../Downloads/md/md/btcusdt_Binance_LinearPerpetual/lobs.csv")

# %%
eth_trades = pd.read_csv("../../../Downloads/md/md/ethusdt_Binance_LinearPerpetual/trades.csv")
eth_lobs = pd.read_csv("../../../Downloads/md/md/ethusdt_Binance_LinearPerpetual/lobs.csv")

# %%
np_btc_trades = btc_trades.to_numpy()
np_btc_lobs = btc_lobs.to_numpy()

trade_columns = btc_trades.columns.to_numpy()
lobs_columns = btc_lobs.columns.to_numpy()

btc_ti = {trade_columns[i]: i for i, col in enumerate(trade_columns)}
btc_li = {lobs_columns[i]: i for i, col in enumerate(lobs_columns)}

# %%
print(btc_trades.shape)
print(btc_lobs.shape)
# print(eth_trades.shape)
# print(eth_lobs.shape)

print(btc_trades.head())
print(btc_lobs.head())
print(np_btc_trades[0])
# Out:
# (5727714, 5)
# (2541356, 42)
#             receive_ts          exchange_ts aggro_side    price   size
# 0  1655942402624789714  1655942402623000000        BID  19977.5  0.001
# 1  1655942405293556247  1655942405292000000        BID  19977.5  0.041
# 2  1655942405293628020  1655942405292000000        BID  19977.5  0.036
# 3  1655942405293832021  1655942405292000000        BID  19977.5  0.001
# 4  1655942405293929517  1655942405292000000        BID  19977.5  0.001
#             receive_ts          exchange_ts  \
# 0  1655942402250125991  1655942402249000000
# 1  1655942402657844605  1655942402655000000
# 2  1655942403346968722  1655942403346000000
# 3  1655942404080791047  1655942404080000000
# 4  1655942404452706766  1655942404452000000
#
#    btcusdt:Binance:LinearPerpetual_ask_price_0  \
# 0                                      19977.5
# 1                                      19977.5
# 2                                      19977.5
# 3                                      19977.5
# 4                                      19977.5
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_0  \
# 0                                      0.079
# 1                                      0.078
# 2                                      0.079
# 3                                      0.079
# 4                                      0.079
#
#    btcusdt:Binance:LinearPerpetual_bid_price_0  \
# 0                                      19977.4
# 1                                      19977.4
# 2                                      19977.4
# 3                                      19977.4
# 4                                      19977.4
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_0  \
# 0                                     12.381
# 1                                     12.381
# 2                                     12.381
# 3                                     12.381
# 4                                     12.381
#
#    btcusdt:Binance:LinearPerpetual_ask_price_1  \
# 0                                      19977.8
# 1                                      19977.8
# 2                                      19977.8
# 3                                      19977.8
# 4                                      19977.8
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_1  \
# 0                                      0.003
# 1                                      0.003
# 2                                      0.003
# 3                                      0.003
# 4                                      0.003
#
#    btcusdt:Binance:LinearPerpetual_bid_price_1  \
# 0                                      19976.7
# 1                                      19977.3
# 2                                      19977.3
# 3                                      19977.3
# 4                                      19977.3
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_1  ...  \
# 0                                      0.066  ...
# 1                                      0.126  ...
# 2                                      0.126  ...
# 3                                      0.126  ...
# 4                                      0.126  ...
#
#    btcusdt:Binance:LinearPerpetual_bid_price_7  \
# 0                                      19975.7
# 1                                      19975.9
# 2                                      19975.9
# 3                                      19975.9
# 4                                      19975.9
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_7  \
# 0                                      4.455
# 1                                      0.246
# 2                                      0.246
# 3                                      0.246
# 4                                      0.246
#
#    btcusdt:Binance:LinearPerpetual_ask_price_8  \
# 0                                      19980.1
# 1                                      19980.1
# 2                                      19980.1
# 3                                      19980.1
# 4                                      19980.1
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_8  \
# 0                                       0.01
# 1                                       0.01
# 2                                       0.01
# 3                                       0.01
# 4                                       0.01
#
#    btcusdt:Binance:LinearPerpetual_bid_price_8  \
# 0                                      19975.6
# 1                                      19975.8
# 2                                      19975.8
# 3                                      19975.8
# 4                                      19975.8
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_8  \
# 0                                      1.529
# 1                                      0.686
# 2                                      0.686
# 3                                      0.686
# 4                                      0.686
#
#    btcusdt:Binance:LinearPerpetual_ask_price_9  \
# 0                                      19980.2
# 1                                      19980.2
# 2                                      19980.2
# 3                                      19980.2
# 4                                      19980.2
#
#    btcusdt:Binance:LinearPerpetual_ask_vol_9  \
# 0                                       0.01
# 1                                       0.01
# 2                                       0.01
# 3                                       0.01
# 4                                       0.01
#
#    btcusdt:Binance:LinearPerpetual_bid_price_9  \
# 0                                      19975.4
# 1                                      19975.7
# 2                                      19975.7
# 3                                      19975.7
# 4                                      19975.7
#
#    btcusdt:Binance:LinearPerpetual_bid_vol_9
# 0                                      1.641
# 1                                      4.455
# 2                                      4.455
# 3                                      4.455
# 4                                      4.455
#
# [5 rows x 42 columns]
# [1655942402624789714 1655942402623000000 'BID' 19977.5 0.001]

# %%
def load_md_from_file(pref, trades, lobs, ti, li) -> list[MdUpdate]:
    # TODO: load actual md
    pref_ask_price = pref + 'ask_price_'
    pref_ask_size = pref + 'ask_vol_'
    pref_bid_price = pref + 'bid_price_'
    pref_bid_size = pref + 'bid_vol_'
    
    mds = []
    i_tr = 0
    
    start_sec = time.time()
    print('Started parsing csv files...')
    for i_lobs in range(lobs.shape[0]):
        d = lobs[i_lobs]
        asks = [(d[li[pref_ask_price + str(i)]], d[li[pref_ask_size + str(i)]]) for i in range(10)]
        bids = [(d[li[pref_bid_price + str(i)]], d[li[pref_bid_size + str(i)]]) for i in range(10)]
        book = OrderbookSnapshotUpdate(timestamp = d[li[' exchange_ts']], asks = asks, bids = bids)
        
        anon_trades = []        
        while i_tr < trades.shape[0] and trades[i_tr][ti['exchange_ts']] < lobs[i_lobs][li[' exchange_ts']]:
            d = trades[i_tr]
            at = AnonTrade(timestamp=d[ti['exchange_ts']], side=d[ti['aggro_side']].lower(), size=d[ti['size']], price=d[ti['price']])    
            anon_trades.append(at)

            i_tr += 1
            if i_tr % 300000 == 0:
                print('Trade progress: %d, %.2f%%' % (i_tr, i_tr / trades.shape[0] * 100))
        
        mds.append(MdUpdate(orderbook = book, trades = anon_trades))
        
        if i_lobs % 300000 == 0:
            print('Lobs progress: %d, %.2f%%' % (i_lobs, i_lobs / lobs.shape[0] * 100))
            
    print('Finished in %d seconds' % (time.time() - start_sec))
    return mds
                 

loaded_md = load_md_from_file('btcusdt:Binance:LinearPerpetual_', np_btc_trades, np_btc_lobs, btc_ti, btc_li)
# Out:
# Started parsing csv files...
# Lobs progress: 0, 0.00%
# Trade progress: 100000, 1.75%
# Trade progress: 200000, 3.49%
# Trade progress: 300000, 5.24%
# Lobs progress: 100000, 3.93%
# Trade progress: 400000, 6.98%
# Trade progress: 500000, 8.73%
# Lobs progress: 200000, 7.87%
# Trade progress: 600000, 10.48%
# Lobs progress: 300000, 11.80%
# Trade progress: 700000, 12.22%
# Trade progress: 800000, 13.97%
# Lobs progress: 400000, 15.74%
# Trade progress: 900000, 15.71%
# Trade progress: 1000000, 17.46%
# Lobs progress: 500000, 19.67%
# Trade progress: 1100000, 19.20%
# Lobs progress: 600000, 23.61%
# Trade progress: 1200000, 20.95%
# Trade progress: 1300000, 22.70%
# Lobs progress: 700000, 27.54%
# Trade progress: 1400000, 24.44%
# Trade progress: 1500000, 26.19%
# Lobs progress: 800000, 31.48%
# Trade progress: 1600000, 27.93%
# Trade progress: 1700000, 29.68%
# Lobs progress: 900000, 35.41%
# Trade progress: 1800000, 31.43%
# Trade progress: 1900000, 33.17%
# Lobs progress: 1000000, 39.35%
# Trade progress: 2000000, 34.92%
# Trade progress: 2100000, 36.66%
# Trade progress: 2200000, 38.41%
# Lobs progress: 1100000, 43.28%
# Trade progress: 2300000, 40.16%
# Trade progress: 2400000, 41.90%
# Lobs progress: 1200000, 47.22%
# Trade progress: 2500000, 43.65%
# Trade progress: 2600000, 45.39%
# Lobs progress: 1300000, 51.15%
# Trade progress: 2700000, 47.14%
# Trade progress: 2800000, 48.89%
# Trade progress: 2900000, 50.63%
# Lobs progress: 1400000, 55.09%
# Trade progress: 3000000, 52.38%
# Trade progress: 3100000, 54.12%
# Trade progress: 3200000, 55.87%
# Lobs progress: 1500000, 59.02%
# Trade progress: 3300000, 57.61%
# Trade progress: 3400000, 59.36%
# Lobs progress: 1600000, 62.96%
# Trade progress: 3500000, 61.11%
# Trade progress: 3600000, 62.85%
# Trade progress: 3700000, 64.60%
# Lobs progress: 1700000, 66.89%
# Trade progress: 3800000, 66.34%
# Trade progress: 3900000, 68.09%
# Lobs progress: 1800000, 70.83%
# Trade progress: 4000000, 69.84%
# Trade progress: 4100000, 71.58%
# Lobs progress: 1900000, 74.76%
# Trade progress: 4200000, 73.33%
# Lobs progress: 2000000, 78.70%
# Trade progress: 4300000, 75.07%
# Trade progress: 4400000, 76.82%
# Trade progress: 4500000, 78.57%
# Lobs progress: 2100000, 82.63%
# Trade progress: 4600000, 80.31%
# Trade progress: 4700000, 82.06%
# Trade progress: 4800000, 83.80%
# Trade progress: 4900000, 85.55%
# Lobs progress: 2200000, 86.57%
# Trade progress: 5000000, 87.29%
# Trade progress: 5100000, 89.04%
# Lobs progress: 2300000, 90.50%
# Trade progress: 5200000, 90.79%
# Trade progress: 5300000, 92.53%
# Trade progress: 5400000, 94.28%
# Lobs progress: 2400000, 94.44%
# Trade progress: 5500000, 96.02%
# Trade progress: 5600000, 97.77%
# Lobs progress: 2500000, 98.37%
# Trade progress: 5700000, 99.52%
# Finished in 107 seconds

# %%
class Strategy:
    def __init__(self, max_position: float) -> None:
        self.max_position = max_position
        self.position = 0
        self.cur_balance = 0
        self.total_executed_trades = 0
        self.total_canceled_trades = 0
        
        self.t0_cancel = 10 * 1000 * 1000 * 1000 # 10,000 seconds
        self.active_positions = SortedList()

    
    def get_best_ask(self, md):
        return md.orderbook.asks[0][0]
    
    
    def get_best_bid(self, md):
        return md.orderbook.bids[0][0]
    
    
    def get_PNL(self, md):
        price = (self.get_best_ask(md) + self.get_best_bid(md)) / 2
        
        return price * self.position + self.cur_balance
    
    
    def smart_AI(self, md):
        is_ask = random.randint(0, 1)
        if self.position > self.max_position:
            is_ask = 1
        if self.position < -self.max_position:
            is_ask = 0
            
        if is_ask:
            side = 'ask'
            size = 0.001
            price = self.get_best_ask(md)
        else:
            side = 'bid'
            size = 0.001
            price = self.get_best_bid(md)
        
        return side, size, price
    
    
    def get_time(self, md):
        return md.orderbook.timestamp
    
    
    def print_stats(self, counter, md):
        if counter % 10000 == 0:
            print('Iteration %d - executed %d, canceled %d, position: %0.4f, balance: %.5f, PNL: %.3f' % 
                  (counter, self.total_executed_trades, self.total_canceled_trades, self.position, self.cur_balance, self.get_PNL(md)))
        return counter + 1
        
    
    def run(self, sim: "Sim"):
        counter = 0
        while True:
            try:
                md, executed = sim.tick()
                if md == None:
                    print('End of data!')
                    break
                
                # calculate statistics
                self.total_executed_trades += len(executed)
                for order in executed:
                    if order.side == 'ask':
                        self.position -= order.size
                        self.cur_balance += order.size * order.price
                    if order.side == 'bid':
                        self.position += order.size
                        self.cur_balance -= order.size * order.price
                
                # place order
                side, size, price = self.smart_AI(md)
                order_id = sim.place_order(side, size, price)
                
                # record it
                self.active_positions.add((self.get_time(md), order_id))
                
                # cancel old orders
                while len(self.active_positions) and self.active_positions[0][0] + self.t0_cancel < self.get_time(md):
                    timestamp, order_id = self.active_positions.pop(0)
                    sim.cancel_order(order_id)
                    self.total_canceled_trades += 1
                    
                counter = self.print_stats(counter, md)
            except StopIteration:
                break

# %%
class Sim:
    def __init__(self, execution_latency: float, md_latency: float) -> None:
        self.md = iter(loaded_md)
        self.cur_time = 0
        self.execution_latency = execution_latency
        self.md_latency = md_latency
        
        self.unique_id = 1
        self.queue = {}
        self.arrived_orders = {}
        self.inside_book = {}

    
    def gen_id(self):
        ans = self.unique_id
        self.unique_id += 1
        return ans
        
        
    def tick(self) -> MdUpdate:
        md = next(self.md, None)
        if md == None: return None, None
        
        self.cur_time = md.orderbook.timestamp
        self.prepare_orders()
        executed = self.execute_orders(md)

        return md, executed

    
    def prepare_orders(self):
        processed_ids = []
        for order in self.queue.values():
            if order.timestamp + self.execution_latency <= self.cur_time:
                self.arrived_orders[order.order_id] = order
                processed_ids.append(order.order_id)

        for order_id in processed_ids:     
            self.queue.pop(order_id)

        
    def matches_book(self, order, md):
        book = md.orderbook
        if order.side == 'bid': # buying
            if book.asks[0][0] <= order.price:
                return (True, book.asks[0][0])
        if order.side == 'ask':
            if book.bids[0][0] >= order.price:
                return (True, book.bids[0][0])
        return (False, -1)
    
    
    def matches_trade_flow(self, order, condensed_trades):
        asks, bids = condensed_trades
        if order.side == 'bid':
            return bids[0] and bids[1] <= order.price
        if order.side == 'ask':
            return asks[0] and asks[1] >= order.price
        
    
    def get_condensed_trades(self, md):
        mn_bid, mx_ask = 0, 0
        exist_bid, exist_ask = False, False
        
        for tr in md.trades:
            if tr.side == 'bid':
                if not exist_bid or tr.price < mn_bid:
                    mn_bid = tr.price
                    exist_bid = True
            if tr.side == 'ask':
                if not exist_ask or tr.price > mx_ask:
                    mx_ask = tr.price
                    exist_ask = True
            
        return ((exist_ask, mx_ask), (exist_bid, mn_bid))
    
    
    def execute_orders(self, md):
        executed = []
        
        # Market orders
        for order in self.arrived_orders.values():
            matched, price = self.matches_book(order, md)
            if matched:
                executed.append(OwnTrade(self.cur_time, self.gen_id(), order.order_id, order.side, order.size, price))
            else:
                self.inside_book[order.order_id] = order
        self.arrived_orders = {}
        
        # Limit orders
        condensed_trades = self.get_condensed_trades(md)
        processed_ids = []
        
        for order in self.inside_book.values():
            if self.matches_trade_flow(order, condensed_trades):
                executed.append(OwnTrade(self.cur_time, self.gen_id(), order.order_id, order.side, order.size, order.price))
                processed_ids.append(order.order_id)

        for order_id in processed_ids:        
            self.inside_book.pop(order_id)
        
        return executed

    
    def place_order(self, side, size, price):
        order_id = self.gen_id()
        self.queue[order_id] = Order(self.cur_time, order_id, side, size, price)
        return order_id

        
    def cancel_order(self, order_id):
        canceled = False
        if order_id in self.queue:
            self.queue.pop(order_id)
            canceled = True
        if order_id in self.arrived_orders:
            self.arrived_orders.pop(order_id)
            canceled = True
        if order_id in self.inside_book:
            self.inside_book.pop(order_id)
            canceled = True
        return canceled

# %%
strategy = Strategy(10)
sim = Sim(10, 10)
strategy.run(sim)
# Out:
# Iteration 0 - executed 0, canceled 0, position: 0.0000, balance: 0.00000, PNL: 0.000
# Iteration 10000 - executed 8265, canceled 9703, position: -0.0870, balance: 1735.85930, PNL: -4.075
# Iteration 20000 - executed 16866, canceled 19718, position: -0.3900, balance: 7792.27950, PNL: -31.920
# Iteration 30000 - executed 25476, canceled 29764, position: -0.5280, balance: 10558.89080, PNL: -91.952
# Iteration 40000 - executed 34142, canceled 39699, position: -0.4120, balance: 8217.06540, PNL: -83.148
# Iteration 50000 - executed 43064, canceled 49772, position: -0.4380, balance: 8689.80620, PNL: -213.902
# Iteration 60000 - executed 52055, canceled 59697, position: 0.1150, balance: -2546.31740, PNL: -215.975
# Iteration 70000 - executed 61000, canceled 69697, position: -0.0720, balance: 1245.43750, PNL: -217.642
# Iteration 80000 - executed 69438, canceled 79708, position: -0.3240, balance: 6359.11820, PNL: -215.441
# Iteration 90000 - executed 77961, canceled 89697, position: -0.6990, balance: 13968.76070, PNL: -296.816
# Iteration 100000 - executed 86822, canceled 99697, position: -0.4640, balance: 9158.87160, PNL: -310.092
# Iteration 110000 - executed 95368, canceled 109699, position: 0.0280, balance: -885.08560, PNL: -314.226
# Iteration 120000 - executed 103222, canceled 119698, position: 0.2460, balance: -5337.83720, PNL: -324.246
# Iteration 130000 - executed 111280, canceled 129699, position: 0.4160, balance: -8804.35730, PNL: -341.191
# Iteration 140000 - executed 119547, canceled 139733, position: -0.1290, balance: 2284.52800, PNL: -349.033
# Iteration 150000 - executed 127747, canceled 149696, position: -0.2670, balance: 5102.50780, PNL: -361.994
# Iteration 160000 - executed 136596, canceled 159696, position: -0.2840, balance: 5439.97080, PNL: -387.894
# Iteration 170000 - executed 144876, canceled 169699, position: 0.5920, balance: -12507.82250, PNL: -399.262
# Iteration 180000 - executed 152501, canceled 179704, position: 0.8810, balance: -18422.31880, PNL: -414.282
# Iteration 190000 - executed 160706, canceled 189700, position: 1.2960, balance: -26904.84980, PNL: -453.036
# Iteration 200000 - executed 168862, canceled 199702, position: 1.0760, balance: -22424.75780, PNL: -513.363
# Iteration 210000 - executed 176783, canceled 209701, position: 0.5810, balance: -12349.61030, PNL: -508.336
# Iteration 220000 - executed 184265, canceled 219700, position: 0.1970, balance: -4543.05420, PNL: -526.333
# Iteration 230000 - executed 191370, canceled 229697, position: 0.4280, balance: -9252.93060, PNL: -539.428
# Iteration 240000 - executed 198680, canceled 239700, position: 0.1780, balance: -4169.55390, PNL: -541.709
# Iteration 250000 - executed 205965, canceled 249699, position: -0.0770, balance: 1021.39200, PNL: -547.102
# Iteration 260000 - executed 212902, canceled 259700, position: -0.0520, balance: 507.35420, PNL: -551.587
# Iteration 270000 - executed 220174, canceled 269700, position: -0.0580, balance: 604.63240, PNL: -578.843
# Iteration 280000 - executed 227916, canceled 279702, position: 0.1120, balance: -2874.99880, PNL: -590.619
# Iteration 290000 - executed 235649, canceled 289698, position: 0.0090, balance: -774.62580, PNL: -590.708
# Iteration 300000 - executed 243809, canceled 299700, position: 0.3410, balance: -7563.32430, PNL: -597.257
# Iteration 310000 - executed 250838, canceled 309699, position: 1.1880, balance: -24849.49860, PNL: -675.659
# Iteration 320000 - executed 258927, canceled 319699, position: 1.2010, balance: -25115.78160, PNL: -753.557
# Iteration 330000 - executed 266706, canceled 329700, position: 0.2940, balance: -6702.01000, PNL: -725.181
# Iteration 340000 - executed 274050, canceled 339700, position: 0.4760, balance: -10412.91100, PNL: -751.944
# Iteration 350000 - executed 281556, canceled 349699, position: 0.0460, balance: -1687.32330, PNL: -752.495
# Iteration 360000 - executed 288896, canceled 359700, position: 0.1820, balance: -4455.17310, PNL: -759.672
# Iteration 370000 - executed 296373, canceled 369697, position: 0.9210, balance: -19457.66440, PNL: -787.106
# Iteration 380000 - executed 302889, canceled 379702, position: 1.0310, balance: -21694.11610, PNL: -783.632
# Iteration 390000 - executed 309889, canceled 389770, position: 1.4250, balance: -29689.59840, PNL: -858.500
# Iteration 400000 - executed 317408, canceled 399701, position: 0.7380, balance: -15796.02280, PNL: -857.095
# Iteration 410000 - executed 325397, canceled 409701, position: 0.8170, balance: -17399.99740, PNL: -850.559
# Iteration 420000 - executed 332241, canceled 419702, position: 1.6430, balance: -34121.30160, PNL: -907.482
# Iteration 430000 - executed 340361, canceled 429703, position: 1.5250, balance: -31738.69970, PNL: -906.936
# Iteration 440000 - executed 348106, canceled 439699, position: 1.7320, balance: -35924.96350, PNL: -987.666
# Iteration 450000 - executed 355594, canceled 449701, position: 1.5900, balance: -33063.59170, PNL: -946.307
# Iteration 460000 - executed 363399, canceled 459705, position: 1.7450, balance: -36198.03990, PNL: -976.524
# Iteration 470000 - executed 371020, canceled 469700, position: 1.3280, balance: -27796.12450, PNL: -932.610
# Iteration 480000 - executed 378965, canceled 479697, position: 1.6430, balance: -34181.34380, PNL: -871.737
# Iteration 490000 - executed 386535, canceled 489700, position: 2.1970, balance: -45418.60830, PNL: -878.717
# Iteration 500000 - executed 394485, canceled 499703, position: 2.0550, balance: -42547.12770, PNL: -723.254
# Iteration 510000 - executed 402170, canceled 509700, position: 2.6920, balance: -55508.47320, PNL: -783.478
# Iteration 520000 - executed 409033, canceled 519698, position: 3.0930, balance: -63668.03550, PNL: -802.965
# Iteration 530000 - executed 416353, canceled 529701, position: 2.8990, balance: -59735.84380, PNL: -723.075
# Iteration 540000 - executed 424104, canceled 539698, position: 3.2560, balance: -67011.06530, PNL: -701.486
# Iteration 550000 - executed 431950, canceled 549700, position: 3.9800, balance: -81742.41510, PNL: -973.290
# Iteration 560000 - executed 438863, canceled 559702, position: 3.0390, balance: -62635.93610, PNL: -882.392
# Iteration 570000 - executed 445867, canceled 569701, position: 2.8490, balance: -58793.18450, PNL: -906.775
# Iteration 580000 - executed 453506, canceled 579703, position: 2.4340, balance: -50357.00450, PNL: -783.605
# Iteration 590000 - executed 461570, canceled 589700, position: 2.6220, balance: -54193.94020, PNL: -717.070
# Iteration 600000 - executed 469452, canceled 599697, position: 3.1060, balance: -64087.68420, PNL: -759.295
# Iteration 610000 - executed 477252, canceled 609700, position: 3.6480, balance: -75141.64820, PNL: -810.183
# Iteration 620000 - executed 484484, canceled 619700, position: 3.8960, balance: -80199.53230, PNL: -823.792
# Iteration 630000 - executed 492175, canceled 629703, position: 4.4610, balance: -91708.54270, PNL: -1027.788
# Iteration 640000 - executed 499752, canceled 639698, position: 4.4520, balance: -91529.24250, PNL: -1092.873
# Iteration 650000 - executed 507859, canceled 649700, position: 4.4270, balance: -91029.42340, PNL: -1111.077
# Iteration 660000 - executed 515492, canceled 659699, position: 4.6120, balance: -94792.82720, PNL: -1118.265
# Iteration 670000 - executed 523033, canceled 669699, position: 4.2410, balance: -87257.85780, PNL: -1022.424
# Iteration 680000 - executed 530167, canceled 679696, position: 3.5630, balance: -73475.29160, PNL: -984.453
# Iteration 690000 - executed 537810, canceled 689700, position: 3.0060, balance: -62134.75850, PNL: -788.160
# Iteration 700000 - executed 546354, canceled 699754, position: 2.5240, balance: -52280.79750, PNL: -398.589
# Iteration 710000 - executed 555206, canceled 709698, position: 2.5380, balance: -52579.03190, PNL: -278.339
# Iteration 720000 - executed 563860, canceled 719697, position: 2.6580, balance: -55052.94860, PNL: -395.564
# Iteration 730000 - executed 572403, canceled 729700, position: 2.9770, balance: -61616.66100, PNL: -443.925
# Iteration 740000 - executed 579966, canceled 739701, position: 3.0140, balance: -62380.18710, PNL: -379.042
# Iteration 750000 - executed 587933, canceled 749704, position: 3.6670, balance: -75802.80550, PNL: -442.105
# Iteration 760000 - executed 596203, canceled 759698, position: 3.3630, balance: -69552.71220, PNL: -335.278
# Iteration 770000 - executed 603962, canceled 769698, position: 3.8920, balance: -80446.39320, PNL: -462.096
# Iteration 780000 - executed 612463, canceled 779699, position: 4.7190, balance: -97420.17840, PNL: -775.294
# Iteration 790000 - executed 620834, canceled 789699, position: 4.6740, balance: -96502.37950, PNL: -736.092
# Iteration 800000 - executed 628992, canceled 799702, position: 5.2680, balance: -108671.04110, PNL: -827.969
# Iteration 810000 - executed 636418, canceled 809700, position: 5.5140, balance: -113707.77720, PNL: -996.379
# Iteration 820000 - executed 643603, canceled 819698, position: 4.8110, balance: -99332.24250, PNL: -856.605
# Iteration 830000 - executed 650837, canceled 829700, position: 4.1150, balance: -85088.23820, PNL: -813.244
# Iteration 840000 - executed 658486, canceled 839700, position: 4.5580, balance: -94156.17150, PNL: -992.703
# Iteration 850000 - executed 665993, canceled 849625, position: 4.4490, balance: -91935.45210, PNL: -982.988
# Iteration 860000 - executed 674354, canceled 859701, position: 3.7800, balance: -78238.32850, PNL: -676.698
# Iteration 870000 - executed 682624, canceled 869703, position: 3.7080, balance: -76759.09670, PNL: -448.642
# Iteration 880000 - executed 691464, canceled 879696, position: 3.6620, balance: -75811.05710, PNL: -277.363
# Iteration 890000 - executed 699853, canceled 889702, position: 4.0830, balance: -84483.51140, PNL: -568.266
# Iteration 900000 - executed 707872, canceled 899700, position: 3.8940, balance: -80603.60990, PNL: -422.451
# Iteration 910000 - executed 715122, canceled 909708, position: 3.9620, balance: -82005.48770, PNL: -635.517
# Iteration 920000 - executed 723018, canceled 919702, position: 4.2460, balance: -87834.39600, PNL: -839.588
# Iteration 930000 - executed 730403, canceled 929701, position: 4.2310, balance: -87534.60870, PNL: -814.975
# Iteration 940000 - executed 737991, canceled 939704, position: 4.5710, balance: -94508.16570, PNL: -860.489
# Iteration 950000 - executed 745641, canceled 949701, position: 4.4290, balance: -91603.61660, PNL: -839.455
# Iteration 960000 - executed 753969, canceled 959700, position: 4.3770, balance: -90552.40150, PNL: -539.615
# Iteration 970000 - executed 761921, canceled 969701, position: 4.2390, balance: -87717.76260, PNL: -512.843
# Iteration 980000 - executed 770150, canceled 979701, position: 4.0560, balance: -83951.69370, PNL: -476.577
# Iteration 990000 - executed 778141, canceled 989701, position: 4.0010, balance: -82824.58530, PNL: -458.199
# Iteration 1000000 - executed 785582, canceled 999698, position: 4.4060, balance: -91177.58290, PNL: -391.072
# Iteration 1010000 - executed 794083, canceled 1009700, position: 4.5690, balance: -94538.56000, PNL: -736.305
# Iteration 1020000 - executed 802540, canceled 1019699, position: 4.4320, balance: -91724.05520, PNL: -562.026
# Iteration 1030000 - executed 811029, canceled 1029702, position: 4.6450, balance: -96093.55600, PNL: -898.229
# Iteration 1040000 - executed 819468, canceled 1039698, position: 4.2660, balance: -88322.53020, PNL: -752.002
# Iteration 1050000 - executed 827805, canceled 1049699, position: 3.5870, balance: -74365.56810, PNL: -518.026
# Iteration 1060000 - executed 836827, canceled 1059806, position: 3.3310, balance: -69081.02850, PNL: -62.209
# Iteration 1070000 - executed 845867, canceled 1069698, position: 3.2430, balance: -67262.04040, PNL: -53.946
# Iteration 1080000 - executed 855026, canceled 1079796, position: 3.2380, balance: -67164.64990, PNL: 75.172
# Iteration 1090000 - executed 863976, canceled 1089698, position: 3.3400, balance: -69286.11940, PNL: -6.002
# Iteration 1100000 - executed 873022, canceled 1099699, position: 3.1920, balance: -66224.86200, PNL: -91.570
# Iteration 1110000 - executed 880925, canceled 1109699, position: 3.0810, balance: -63932.11870, PNL: -10.150
# Iteration 1120000 - executed 889309, canceled 1119697, position: 3.3470, balance: -69443.50600, PNL: -229.722
# Iteration 1130000 - executed 897692, canceled 1129698, position: 2.9220, balance: -60654.54260, PNL: -144.159
# Iteration 1140000 - executed 905457, canceled 1139701, position: 2.3690, balance: -49200.24000, PNL: -95.016
# Iteration 1150000 - executed 913529, canceled 1149704, position: 2.7190, balance: -56466.82010, PNL: -165.439
# Iteration 1160000 - executed 921928, canceled 1159700, position: 3.0860, balance: -64060.30790, PNL: -272.225
# Iteration 1170000 - executed 930074, canceled 1169702, position: 2.9780, balance: -61830.28070, PNL: -277.254
# Iteration 1180000 - executed 937843, canceled 1179704, position: 3.1010, balance: -64379.77120, PNL: -263.030
# Iteration 1190000 - executed 945463, canceled 1189700, position: 2.8030, balance: -58222.24700, PNL: -246.817
# Iteration 1200000 - executed 953035, canceled 1199701, position: 2.7430, balance: -56983.21380, PNL: -274.843
# Iteration 1210000 - executed 960742, canceled 1209701, position: 2.1220, balance: -44160.23680, PNL: -324.067
# Iteration 1220000 - executed 968233, canceled 1219701, position: 2.2430, balance: -46666.10500, PNL: -301.388
# Iteration 1230000 - executed 975930, canceled 1229702, position: 2.2420, balance: -46652.97390, PNL: -355.562
# Iteration 1240000 - executed 983376, canceled 1239700, position: 1.9380, balance: -40378.28800, PNL: -331.553
# Iteration 1250000 - executed 991413, canceled 1249700, position: 2.3010, balance: -47884.98710, PNL: -420.534
# Iteration 1260000 - executed 999384, canceled 1259700, position: 2.2240, balance: -46298.34350, PNL: -373.077
# Iteration 1270000 - executed 1006269, canceled 1269700, position: 2.4670, balance: -51319.93570, PNL: -446.325
# Iteration 1280000 - executed 1013715, canceled 1279701, position: 2.3710, balance: -49346.71180, PNL: -411.998
# Iteration 1290000 - executed 1021856, canceled 1289699, position: 2.2160, balance: -46157.28950, PNL: -404.535
# Iteration 1300000 - executed 1030317, canceled 1299697, position: 2.9270, balance: -60831.79120, PNL: -386.753
# Iteration 1310000 - executed 1038875, canceled 1309701, position: 2.7770, balance: -57735.68730, PNL: -363.006
# Iteration 1320000 - executed 1047448, canceled 1319698, position: 2.6200, balance: -54497.10390, PNL: -235.987
# Iteration 1330000 - executed 1056139, canceled 1329795, position: 2.3910, balance: -49760.83600, PNL: -163.964
# Iteration 1340000 - executed 1064566, canceled 1339700, position: 2.6160, balance: -54429.53290, PNL: -240.793
# Iteration 1350000 - executed 1073507, canceled 1349698, position: 2.8190, balance: -58633.07560, PNL: -575.348
# Iteration 1360000 - executed 1082398, canceled 1359701, position: 2.7180, balance: -56557.15270, PNL: -590.407
# Iteration 1370000 - executed 1091068, canceled 1369698, position: 3.1420, balance: -65276.27380, PNL: -836.839
# Iteration 1380000 - executed 1099634, canceled 1379700, position: 2.6980, balance: -56163.90570, PNL: -711.777
# Iteration 1390000 - executed 1108084, canceled 1389701, position: 2.6840, balance: -55883.85700, PNL: -773.956
# Iteration 1400000 - executed 1116436, canceled 1399699, position: 1.8860, balance: -39475.46950, PNL: -595.674
# Iteration 1410000 - executed 1124175, canceled 1409703, position: 2.2370, balance: -46706.87050, PNL: -664.377
# Iteration 1420000 - executed 1131988, canceled 1419699, position: 2.2160, balance: -46281.23470, PNL: -624.654
# Iteration 1430000 - executed 1139704, canceled 1429701, position: 1.7760, balance: -37226.27240, PNL: -647.865
# Iteration 1440000 - executed 1148182, canceled 1439787, position: 2.1300, balance: -44520.85640, PNL: -720.495
# Iteration 1450000 - executed 1157325, canceled 1449700, position: 2.1070, balance: -44054.93520, PNL: -861.119
# Iteration 1460000 - executed 1166073, canceled 1459774, position: 1.9890, balance: -41640.89740, PNL: -873.259
# Iteration 1470000 - executed 1174932, canceled 1469804, position: 2.0340, balance: -42562.33310, PNL: -1015.544
# Iteration 1480000 - executed 1183908, canceled 1479696, position: 2.1420, balance: -44773.82950, PNL: -967.680
# Iteration 1490000 - executed 1192924, canceled 1489697, position: 2.0400, balance: -42692.57810, PNL: -962.644
# Iteration 1500000 - executed 1201873, canceled 1499697, position: 2.2470, balance: -46925.95140, PNL: -1069.737
# Iteration 1510000 - executed 1210560, canceled 1509703, position: 2.1720, balance: -45399.47640, PNL: -1024.756
# Iteration 1520000 - executed 1218812, canceled 1519721, position: 1.6740, balance: -35226.31330, PNL: -950.745
# Iteration 1530000 - executed 1227423, canceled 1529700, position: 1.7950, balance: -37707.29530, PNL: -967.684
# Iteration 1540000 - executed 1235806, canceled 1539700, position: 1.6360, balance: -34460.48310, PNL: -993.567
# Iteration 1550000 - executed 1244096, canceled 1549698, position: 1.9620, balance: -41134.78170, PNL: -998.246
# Iteration 1560000 - executed 1252685, canceled 1559704, position: 1.7470, balance: -36737.77580, PNL: -879.291
# Iteration 1570000 - executed 1261086, canceled 1569696, position: 1.8620, balance: -39106.18510, PNL: -878.673
# Iteration 1580000 - executed 1269345, canceled 1579699, position: 1.9170, balance: -40238.80300, PNL: -848.383
# Iteration 1590000 - executed 1277986, canceled 1589731, position: 1.4960, balance: -31584.04250, PNL: -799.429
# Iteration 1600000 - executed 1285888, canceled 1599699, position: 2.6000, balance: -54287.91060, PNL: -880.141
# Iteration 1610000 - executed 1293420, canceled 1609700, position: 2.1840, balance: -45744.46800, PNL: -849.618
# Iteration 1620000 - executed 1301118, canceled 1619700, position: 1.9440, balance: -40814.17370, PNL: -845.631
# Iteration 1630000 - executed 1309622, canceled 1629804, position: 2.3100, balance: -48334.68560, PNL: -1093.915
# Iteration 1640000 - executed 1317850, canceled 1639703, position: 2.4720, balance: -51647.43420, PNL: -1171.543
# Iteration 1650000 - executed 1326753, canceled 1649702, position: 2.8470, balance: -59303.69670, PNL: -1444.258
# Iteration 1660000 - executed 1335503, canceled 1659701, position: 2.7850, balance: -58048.11080, PNL: -1415.554
# Iteration 1670000 - executed 1343836, canceled 1669698, position: 3.1320, balance: -65108.90830, PNL: -1450.225
# Iteration 1680000 - executed 1351977, canceled 1679752, position: 3.2810, balance: -68138.49570, PNL: -1417.556
# Iteration 1690000 - executed 1360179, canceled 1689697, position: 2.8890, balance: -60162.38260, PNL: -1322.553
# Iteration 1700000 - executed 1368623, canceled 1699698, position: 3.5190, balance: -72975.71400, PNL: -1479.311
# Iteration 1710000 - executed 1377149, canceled 1709701, position: 3.8190, balance: -79065.67300, PNL: -1651.106
# Iteration 1720000 - executed 1384945, canceled 1719697, position: 3.0990, balance: -64462.33010, PNL: -1593.847
# Iteration 1730000 - executed 1392427, canceled 1729699, position: 2.5970, balance: -54279.77890, PNL: -1506.791
# Iteration 1740000 - executed 1400228, canceled 1739698, position: 2.7680, balance: -57760.98710, PNL: -1582.905
# Iteration 1750000 - executed 1408588, canceled 1749699, position: 2.3240, balance: -48747.97500, PNL: -1537.426
# Iteration 1760000 - executed 1416828, canceled 1759700, position: 2.4220, balance: -50744.97590, PNL: -1544.347
# Iteration 1770000 - executed 1424522, canceled 1769698, position: 2.3500, balance: -49287.86850, PNL: -1584.631
# Iteration 1780000 - executed 1432547, canceled 1779721, position: 1.9870, balance: -41917.37090, PNL: -1508.646
# Iteration 1790000 - executed 1440411, canceled 1789700, position: 2.3250, balance: -48791.49350, PNL: -1531.218
# Iteration 1800000 - executed 1447821, canceled 1799702, position: 3.0630, balance: -63780.99310, PNL: -1683.722
# Iteration 1810000 - executed 1456728, canceled 1809702, position: 3.2440, balance: -67458.36420, PNL: -1814.564
# Iteration 1820000 - executed 1465102, canceled 1819703, position: 2.9300, balance: -61097.23340, PNL: -1641.820
# Iteration 1830000 - executed 1473062, canceled 1829699, position: 2.9840, balance: -62203.67220, PNL: -1614.298
# Iteration 1840000 - executed 1480357, canceled 1839699, position: 3.0690, balance: -63934.43130, PNL: -1650.150
# Iteration 1850000 - executed 1488072, canceled 1849698, position: 3.7040, balance: -76824.54550, PNL: -1784.654
# Iteration 1860000 - executed 1496041, canceled 1859698, position: 3.3190, balance: -69023.74130, PNL: -1651.526
# Iteration 1870000 - executed 1502797, canceled 1869699, position: 4.0030, balance: -82893.96650, PNL: -1829.414
# Iteration 1880000 - executed 1510613, canceled 1879700, position: 3.4330, balance: -71345.86710, PNL: -1674.334
# Iteration 1890000 - executed 1517967, canceled 1889698, position: 3.4110, balance: -70898.47450, PNL: -1587.125
# Iteration 1900000 - executed 1526054, canceled 1899698, position: 3.4600, balance: -71902.43370, PNL: -1515.827
# Iteration 1910000 - executed 1534076, canceled 1909700, position: 3.7920, balance: -78653.51750, PNL: -1586.237
# Iteration 1920000 - executed 1541429, canceled 1919700, position: 3.6150, balance: -75058.55850, PNL: -1541.207
# Iteration 1930000 - executed 1549106, canceled 1929700, position: 3.5920, balance: -74591.77350, PNL: -1498.704
# Iteration 1940000 - executed 1557035, canceled 1939698, position: 3.5890, balance: -74537.93040, PNL: -1443.459
# Iteration 1950000 - executed 1564674, canceled 1949699, position: 3.8660, balance: -80186.18580, PNL: -1379.902
# Iteration 1960000 - executed 1572897, canceled 1959699, position: 4.4350, balance: -91787.86090, PNL: -1334.927
# Iteration 1970000 - executed 1580864, canceled 1969700, position: 4.4940, balance: -92996.18600, PNL: -1286.903
# Iteration 1980000 - executed 1588701, canceled 1979700, position: 4.7550, balance: -98324.13280, PNL: -1290.037
# Iteration 1990000 - executed 1596364, canceled 1989700, position: 4.9120, balance: -101528.66930, PNL: -1361.937
# Iteration 2000000 - executed 1603529, canceled 1999702, position: 5.2990, balance: -109433.34310, PNL: -1250.814
# Iteration 2010000 - executed 1611039, canceled 2009700, position: 6.1870, balance: -127563.29290, PNL: -1296.831
# Iteration 2020000 - executed 1618294, canceled 2019702, position: 6.7280, balance: -138608.00850, PNL: -1313.413
# Iteration 2030000 - executed 1625594, canceled 2029698, position: 6.6920, balance: -137876.57860, PNL: -1363.459
# Iteration 2040000 - executed 1633757, canceled 2039697, position: 6.3010, balance: -129903.91860, PNL: -654.971
# Iteration 2050000 - executed 1641511, canceled 2049700, position: 6.6670, balance: -137413.84860, PNL: -485.336
# Iteration 2060000 - executed 1650209, canceled 2059697, position: 6.4850, balance: -133674.08590, PNL: 447.063
# Iteration 2070000 - executed 1659028, canceled 2069697, position: 6.0280, balance: -124225.89360, PNL: 673.965
# Iteration 2080000 - executed 1667860, canceled 2079700, position: 6.0820, balance: -125360.67100, PNL: 1044.880
# Iteration 2090000 - executed 1676779, canceled 2089697, position: 6.3590, balance: -131128.04180, PNL: 958.881
# Iteration 2100000 - executed 1685659, canceled 2099704, position: 5.9750, balance: -123146.16480, PNL: 1333.699
# Iteration 2110000 - executed 1694465, canceled 2109699, position: 6.1730, balance: -127289.48370, PNL: 1367.256
# Iteration 2120000 - executed 1702728, canceled 2119698, position: 5.9900, balance: -123477.05300, PNL: 1744.796
# Iteration 2130000 - executed 1711549, canceled 2129741, position: 6.2950, balance: -129843.98880, PNL: 897.181
# Iteration 2140000 - executed 1719963, canceled 2139698, position: 5.3130, balance: -109441.95940, PNL: 1210.563
# Iteration 2150000 - executed 1728943, canceled 2149697, position: 5.4850, balance: -113061.05190, PNL: 2224.598
# Iteration 2160000 - executed 1737562, canceled 2159699, position: 6.0620, balance: -125180.09300, PNL: 2070.077
# Iteration 2170000 - executed 1745938, canceled 2169699, position: 6.7660, balance: -139950.74420, PNL: 1565.897
# Iteration 2180000 - executed 1754867, canceled 2179702, position: 7.1010, balance: -146946.02630, PNL: 1135.032
# Iteration 2190000 - executed 1762983, canceled 2189698, position: 6.8670, balance: -142070.34410, PNL: 1279.311
# Iteration 2200000 - executed 1770906, canceled 2199702, position: 6.2100, balance: -128362.66960, PNL: 1420.431
# Iteration 2210000 - executed 1778685, canceled 2209698, position: 5.9190, balance: -122282.81070, PNL: 1545.925
# Iteration 2220000 - executed 1786841, canceled 2219700, position: 6.2850, balance: -129924.12380, PNL: 797.905
# Iteration 2230000 - executed 1794585, canceled 2229699, position: 5.4390, balance: -112322.19020, PNL: 1009.981
# Iteration 2240000 - executed 1802896, canceled 2239704, position: 5.1200, balance: -105697.07640, PNL: 643.020
# Iteration 2250000 - executed 1810767, canceled 2249700, position: 5.4110, balance: -111752.74730, PNL: 612.349
# Iteration 2260000 - executed 1818746, canceled 2259702, position: 4.4380, balance: -91542.11010, PNL: 720.581
# Iteration 2270000 - executed 1825975, canceled 2269701, position: 4.2570, balance: -87780.72350, PNL: 678.672
# Iteration 2280000 - executed 1832678, canceled 2279675, position: 4.4460, balance: -91719.71610, PNL: 791.096
# Iteration 2290000 - executed 1839287, canceled 2289697, position: 4.7090, balance: -97181.00000, PNL: 227.255
# Iteration 2300000 - executed 1846579, canceled 2299701, position: 4.4650, balance: -92134.04020, PNL: 283.646
# Iteration 2310000 - executed 1854556, canceled 2309703, position: 4.3620, balance: -90015.11720, PNL: 321.685
# Iteration 2320000 - executed 1860602, canceled 2319704, position: 4.4720, balance: -92297.78870, PNL: 259.419
# Iteration 2330000 - executed 1867599, canceled 2329702, position: 4.3310, balance: -89385.87320, PNL: 212.339
# Iteration 2340000 - executed 1876115, canceled 2339716, position: 4.1470, balance: -85585.84980, PNL: 351.394
# Iteration 2350000 - executed 1884597, canceled 2349703, position: 4.4110, balance: -91073.82130, PNL: 459.501
# Iteration 2360000 - executed 1892848, canceled 2359703, position: 4.2060, balance: -86830.78570, PNL: 507.435
# Iteration 2370000 - executed 1901481, canceled 2369702, position: 4.1810, balance: -86323.97660, PNL: 733.014
# Iteration 2380000 - executed 1909747, canceled 2379699, position: 4.5110, balance: -93206.45630, PNL: 774.590
# Iteration 2390000 - executed 1918769, canceled 2389728, position: 4.3310, balance: -89435.47850, PNL: 2074.437
# Iteration 2400000 - executed 1927767, canceled 2399719, position: 4.3950, balance: -90792.79680, PNL: 1828.092
# Iteration 2410000 - executed 1936561, canceled 2409702, position: 4.7270, balance: -97796.60290, PNL: 1805.778
# Iteration 2420000 - executed 1945104, canceled 2419703, position: 4.7540, balance: -98370.81740, PNL: 1747.234
# Iteration 2430000 - executed 1953597, canceled 2429700, position: 5.4130, balance: -112237.55040, PNL: 1452.501
# Iteration 2440000 - executed 1961871, canceled 2439702, position: 5.4130, balance: -112243.58140, PNL: 1348.494
# Iteration 2450000 - executed 1970041, canceled 2449702, position: 4.8570, balance: -100583.43860, PNL: 1610.513
# Iteration 2460000 - executed 1978080, canceled 2459704, position: 5.0980, balance: -105667.06180, PNL: 1651.701
# Iteration 2470000 - executed 1984845, canceled 2469702, position: 6.4150, balance: -133391.27300, PNL: 1526.120
# Iteration 2480000 - executed 1992619, canceled 2479703, position: 6.2410, balance: -129731.81910, PNL: 2242.551
# Iteration 2490000 - executed 2000680, canceled 2489702, position: 6.6860, balance: -139140.60130, PNL: 2299.389
# Iteration 2500000 - executed 2008611, canceled 2499705, position: 7.4190, balance: -154645.86900, PNL: 1962.915
# Iteration 2510000 - executed 2015521, canceled 2509705, position: 7.2590, balance: -151274.87840, PNL: 2092.911
# Iteration 2520000 - executed 2022900, canceled 2519711, position: 7.4660, balance: -155656.43060, PNL: 1813.082
# Iteration 2530000 - executed 2030451, canceled 2529706, position: 7.3570, balance: -153366.97520, PNL: 1674.075
# Iteration 2540000 - executed 2038087, canceled 2539703, position: 7.1290, balance: -148569.56840, PNL: 1753.595
# End of data!
